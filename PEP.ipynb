# %%
a = "find all the spaces"
print(a.count(" "))
# Out:
# 3

# %%
a.split("a")
# Out:
# ['find ', 'll the sp', 'ces']

# %%
print(a[::-1])
# Out:
# secaps eht lla dnif

# %%
b = input("Enter the speech: ")
b = b.replace("<"," ")
b = b.replace(">"," ")
b = b.replace("/"," ")

print(b)
# Out:
# Enter the speech:  <h1> Hello </h1>
#  h1  Hello   h1

# %%
data = "    yukkkk         "
print(data)
print(data.strip())

# lstrip -> removes spaces from left side
#rstrip -> remvoes spaces form right side
# Out:
#     yukkkk
# yukkkk
